# %%
import numpy as np
from PIL import Image
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = Image.open("hamza.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=853x853 at 0x25B20ED5AF0>

# %%
plt.imshow(mpimg.imread("hamza.jpg"))

# %% [markdown]
# # Numpy Task - 01

# %%
img = Image.open("hamza.jpg")
img1 = np.asarray(img)

# %%
img1.shape
# Out:
# (853, 853, 3)

# %%
img1 = img1[0:500,0:500]

# %%
img_crop = Image.fromarray(img1)
img_crop.save("hamzaCrop.jpg")

# %%
img = Image.open("hamzacrop.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x25FC15543D0>

# %%
plt.imshow(mpimg.imread("hamzacrop.jpg"))

# %%
img = Image.open("hamza.jpg")

area = (300, 100, 500, 400)
cropped_img = img.crop(area)
img = cropped_img
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x25B20ECF3D0>

# %% [markdown]
# # Numpy Task - 02

# %%
plt.imshow(mpimg.imread("hamza3.jpg"))

# %%
img2 = Image.open("hamza3.jpg")
img3 = np.asarray(img2)
img1 = img1[0:500,0:500]
img3 = img3[0:500,0:500]

# %%
img3.shape
# Out:
# (500, 500, 3)

# %%
final_image = np.vstack((img1,img3))

# %%
final_image2 = Image.fromarray(final_image)

# %%
final_image2.save("finalpic.jpg")

# %%
img= Image.open("finalpic.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x1000 at 0x25FC154F880>

# %% [markdown]
# # Numpy Task - 03

# %%
final_himage = np.hstack((img1,img3))
final_himage2 = Image.fromarray(final_himage)
final_himage2.save("finalhpic.jpg")
img= Image.open("finalhpic.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x500 at 0x25B23108790>

# %% [markdown]
# # Numpy Task - (04-06) in NumpyTask 02 folder
