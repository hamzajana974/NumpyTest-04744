# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter

# %%
img = Image.open("hamza.jpg")
img1 = np.array(img)

# %%
img1.shape
# Out:
# (853, 853, 3)

# %%
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
image = image.imread('hamza.jpg')
# summarize shape of the pixel array
print(image.dtype)
print(image.shape)
# display the array of pixels as an image
pyplot.imshow(image)
pyplot.show()
# Out:
# uint8
# (853, 853, 3)

# %%
from numpy import asarray
# load the image
image = Image.open('hamza.jpg')
# convert image to numpy array
data = asarray(image)
print(type(data))
# summarize shape
print(data.shape)

# create Pillow image
image2 = Image.fromarray(data)
print(type(image2))

# summarize image details
print(image2.mode)
print(image2.size)
# Out:
# <class 'numpy.ndarray'>
# (853, 853, 3)
# <class 'PIL.Image.Image'>
# RGB
# (853, 853)

# %%
print(data)
# Out:
# [[[196 196 208]
#   [196 196 208]
#   [196 196 208]
#   ...
#   [137 128 149]
#   [143 134 155]
#   [134 125 146]]
#
#  [[196 196 208]
#   [196 196 208]
#   [196 196 208]
#   ...
#   [131 122 143]
#   [137 128 149]
#   [130 121 142]]
#
#  [[196 196 208]
#   [196 196 208]
#   [196 196 208]
#   ...
#   [122 113 134]
#   [128 119 140]
#   [121 112 133]]
#
#  ...
#
#  [[ 42  43  29]
#   [ 42  43  29]
#   [ 41  42  28]
#   ...
#   [ 95  92 111]
#   [ 97  94 113]
#   [ 98  95 114]]
#
#  [[ 43  44  30]
#   [ 42  43  29]
#   [ 42  43  29]
#   ...
#   [ 98  95 114]
#   [ 99  96 115]
#   [100  97 116]]
#
#  [[ 43  44  30]
#   [ 43  44  30]
#   [ 42  43  29]
#   ...
#   [ 99  96 115]
#   [100  97 116]
#   [101  98 117]]]

# %% [markdown]
# # Numpy Task - 04

# %%
gry_scl = np.dot(data[...,:3],[0.299,0.587,0.114])
gry_scl
# Out:
# array([[197.368, 197.368, 197.368, ..., 133.085, 139.085, 130.085],
#        [197.368, 197.368, 197.368, ..., 127.085, 133.085, 126.085],
#        [197.368, 197.368, 197.368, ..., 118.085, 124.085, 117.085],
#        ...,
#        [ 41.105,  41.105,  40.105, ...,  95.063,  97.063,  98.063],
#        [ 42.105,  41.105,  41.105, ...,  98.063,  99.063, 100.063],
#        [ 42.105,  42.105,  41.105, ...,  99.063, 100.063, 101.063]])

# %%
final_gry = Image.fromarray(gry_scl)

# %%
img = Image.open("hamza_greyscale.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=432x288 at 0x2E448748850>

# %%
import matplotlib.image as mpimg
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.144])

img = mpimg.imread('hamza.jpg')

gray = rgb2gray(img)

plt.imshow(gray, cmap = plt.get_cmap('gray'))

plt.savefig('hamza_greyscale.jpg')
plt.show()

# %% [markdown]
# # Numpy Task - 05

# %%
from PIL import Image, ImageFilter
blurImage = img.filter(ImageFilter.BLUR)
blurImage.show()
#Save blurImage
blurImage.save('hamzaBlur.jpg')

# %%
img = Image.open('hamzaBlur.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=853x853 at 0x2E446DDF310>

# %% [markdown]
# # Numpy Task - 06

# %%
blurImage.rotate(-90)
# Out:
# <PIL.Image.Image image mode=RGB size=432x288 at 0x2E449186A30>

# %%
final = data[0:3,0:3,2]

# %%
print(final)
# Out:
# [[208 208 208]
#  [208 208 208]
#  [208 208 208]]

# %%
Filter = [[-1,0,1],
          [-1,0,1],
          [-1,0,1]]

# %%
test = final * Filter
